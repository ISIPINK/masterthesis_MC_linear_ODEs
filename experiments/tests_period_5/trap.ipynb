# %%
from random import random
from math import exp,sqrt
from numba import njit, prange
from functools import lru_cache
import numpy as np
import matplotlib.pyplot as plt

#@lru_cache(maxsize=4)
@njit
def f(x): 
    if x<0.5: 
        return exp(x)- 0.5**3/3
    return exp(x) + (x-0.5)**2 - 0.5**3/3
    
@njit(fastmath=True)
def trapezium(n,a,b):
    dx = (b-a)/n
    x,sol = 0,0
    for _ in range(n):
        xx = x + dx
        sol += (f(x)+f(xx))/2 # inefficient
        x = xx
    return sol*dx

@njit(fastmath=True)
def MCtrapezium(n,a,b):
    dx = (b-a)/n
    x,sol,solMC,solMC2 = 0,0,0,0
    for _ in range(n):
        xx = x + dx
        sol += (f(x)+f(xx))/2 # inefficient
        l = 10 # russian roulette rate 
        if random()*l<1:
            U = x + random()*(xx-x) # \sim Uniform(x,xx)
            tmp= l*(f(U)-f(x)-(U-x)*(f(xx)-f(x))/dx)
            solMC += tmp
            solMC2 += tmp**2
        x = xx
    return dx*(sol+solMC), sqrt(solMC2-solMC**2)*dx

def exact(a,b): return exp(b)-exp(a) 
MCtrapezium(100,0,1)
# Out:
# (1.7182829067507412, nan)

# %%
def MCtrap_llplot():
    a,b = 0,1
    DTS = np.power(2,np.array(range(24)))
    errors = np.array([(abs(trapezium(n,a,b)-exact(a,b)))/(exact(a,b)) for n in DTS])
    MCerrors,MCsig = [],[]
    for n in DTS:
        sol,sig = MCtrapezium(n,a,b)
        MCerrors.append((abs(sol-exact(a,b)))/(exact(a,b)))
        MCsig.append(sig)
    plt.plot(np.log(DTS)/np.log(10),np.log(errors)/np.log(10), label = "OG trap")
    plt.plot(np.log(DTS)/np.log(10),np.log(MCerrors)/np.log(10), label = "MC trap")
    plt.plot(np.log(DTS)/np.log(10),np.log(MCsig)/np.log(10), label = "MC std")
    dgs = np.arange(2,3.5,0.5)
    for l in dgs:
        ref = np.array([pow(1/d,l) for d in DTS])
        plt.plot(np.log(DTS)/np.log(10),np.log(ref/10)/np.log(10),label =f"d**-{l}",linestyle="dashed")
    plt.legend()
    plt.title("log log plot")
    plt.show()

MCtrap_llplot()
# Out:
# C:\Users\isido\AppData\Local\Temp\ipykernel_15116\2412102884.py:12: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(DTS)/np.log(10),np.log(MCsig)/np.log(10), label = "MC std")

# %% [markdown]
# Ok we need to improve the code the trapezium rule:

# %%
for n in range(1,10000000,1000000):
    print(len(np.arange(0, 1, 1/n)),n)
# Out:
# 1 1
# 1000001 1000001
# 2000002 2000001
# 3000001 3000001
# 4000001 4000001
# 5000001 5000001
# 6000001 6000001
# 7000001 7000001
# 8000001 8000001
# 9000001 9000001

# %%
from random import random as U
from math import exp
import numpy as np
def f(x): return exp(x)
def trapezium(n): return sum((f(j/n)+f((j+1)/n))/2
    for j in range(n))/n

def MCtrapezium(n, l=100):
    sol = 0
    for j in range(n):
        if U()*l < 1:
            x, xx = j/n, (j+1)/n
            S = x + U()*(xx-x)  # \sim Uniform(x,xx)
            sol += l*(f(S)-f(x)-(S-x)*(f(xx)-f(x))*n)/n
    return sol+trapezium(n)
def exact(a, b): return exp(b)-exp(a)
def error(s): return (s-exact(0, 1))/exact(0, 1)
print(f"  error:{error(trapezium(10000))}")
print(f"MCerror:{error(MCtrapezium(10000,100))}")
# Out:
#   error:8.333344745642098e-10
# MCerror:-1.1221454143983598e-10

# %%
import matplotlib.pyplot as plt
def MCtrap_llplot():
    DTS = np.floor(np.power(2,np.arange(0,17,0.2))).astype(int)
    errors = np.array([(abs(trapezium(n)-exact(0,1)))/(exact(0,1)) for n in DTS])
    MCerrors = np.array([(abs(MCtrapezium(n)-exact(0,1)))/(exact(0,1)) for n in DTS])
    plt.plot(np.log(DTS)/np.log(10),np.log(errors)/np.log(10), label = "OG trap")
    plt.plot(np.log(DTS)/np.log(10),np.log(MCerrors)/np.log(10), label = "MC trap")
    dgs = np.arange(2,3.5,0.5)
    for l in dgs:
        ref = np.array([pow(1/d,l) for d in DTS])
        plt.plot(np.log(DTS)/np.log(10),np.log(ref)/np.log(10),label =f"h**-{l}",linestyle="dashed")
    plt.legend()
    plt.title("log log plot")
    plt.show()

MCtrap_llplot()

# %%
from random import random
from math import exp,cos,sin
from numba import njit, prange
from itertools import product
import numpy as np

u = 2
@njit(fastmath=True)
def f2(x,y): return (cos(x/u)+ ((0 if x<0.5 else (x-0.5)**2) -1/24))*(cos(y/u) + ((0 if y<0.5 else (y-0.5)**2) -1/24))

@njit(fastmath=True)
def trapezium2(n):
    sol = 0
    for j in range(n):
        for k in range(n):
            x,y = j/n, k/n
            sol += (f2(x+1/n,y)+f2(x,y+1/n))/(2*n**2)
    return sol

@njit(fastmath=True)
def MCtrapezium2(n,l=100):
    sol = 0
    for j in range(n):
        for k in range(n):
            if random()*l<1:
                x,y = j/n, k/n
                X,Y = x + random()/n, y + random()/n
                control = f2(x,y)+(f2(x+1/n,y)-f2(x,y))*(X-x)*n+(f2(x,y+1/n)-f2(x,y))*(Y-y)*n
                sol += l*(f2(X,Y)-control)/n**2 
    return sol+trapezium2(n)

def exact2(): return (sin(1/u))**2 * u**2
def error2(s): return abs(s-exact2())/exact2()

print(error2(trapezium2(100)))
print(error2(MCtrapezium2(100)))
# Out:
# 1.2772679864093832e-05
# 2.9180204440066038e-06

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import cos

# Define the range of x and y values
x_values = np.linspace(0, 1, 100)
y_values = np.linspace(0, 1, 100)

# Set the value of u

# Calculate the function values for each (x, y) pair
f_values = np.zeros((100, 100))
for i, x in enumerate(x_values):
    for j, y in enumerate(y_values):
        f_values[i, j] = f2(x, y)

# Create a heatmap plot
plt.imshow(f_values, cmap='viridis', extent=[0, 1, 0, 1], origin='lower')
plt.colorbar(label='f2(X, Y)')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Visualization of f2(X, Y)')
plt.show()

# %%
import matplotlib.pyplot as plt
def MCtrap2_llplot():
    DTS = np.floor(np.power(2,np.arange(0,12,0.1))).astype(int)
    errors = np.array([error2(trapezium2(n)) for n in DTS])
    MCerrors = np.array([error2(MCtrapezium2(n,100)) for n in DTS])
    plt.plot(np.log(DTS)/np.log(10),np.log(errors)/np.log(10), label = "OG trap")
    plt.plot(np.log(DTS)/np.log(10),np.log(MCerrors)/np.log(10), label = "MC trap")
    dgs = np.arange(2,4,0.5)
    for l in dgs:
        ref = np.array([pow(1/d,l) for d in DTS])
        plt.plot(np.log(DTS)/np.log(10),np.log(ref/5)/np.log(10),label =f"d**-{l}",linestyle="dashed")
    plt.legend()
    plt.title("log log plot")
    plt.show()

MCtrap2_llplot()

# %%
from random import random as U
from math import exp,sin,cos
import numpy as np
from numba import njit, prange

@njit
def f(x): return exp(x)

@njit
def trapezium(n): 
    sol = 0.0
    for j in range(n):
        if j/n>1: 
            print("you")
        sol +=(f(j/n)+f((j+1)/n))/2
    return sol/n

@njit
def MCtrapezium(n, l=100):
    sol = 0
    for j in range(n):
        if U()*l < 1:
            x, xx = j/n, (j+1)/n
            S = x + U()*(xx-x)  # \sim Uniform(x,xx)
            sol += l*(f(S)-f(x)-(S-x)*(f(xx)-f(x))*n)/n
    return sol+trapezium(n)

@njit
def exact(a, b): return exp(b)-exp(a)
@njit
def error(s): return (s-exact(0, 1))/exact(0, 1)

# %%
print(trapezium(100))
print(f"  error:{error(trapezium(10000))}")
print(f"MCerror:{error(MCtrapezium(10000,100))}")
# Out:
# 1.718296147450418
#   error:8.333344745642098e-10
# MCerror:6.282043384164965e-11

# %%
import matplotlib.pyplot as plt
ls = np.arange(1,100,5)
MCerrors = np.zeros(len(ls))
for _ in range(1000):
    MCerrors += np.array([(abs(MCtrapezium(1000,l)-exact(0,1)))/(exact(0,1)) for l in ls])/1000
plt.plot(np.log(ls), np.log(MCerrors))
plt.plot(np.log(ls),np.log(np.sqrt(ls)*MCerrors[0])+0.75)
plt.show()

# %%
import matplotlib.pyplot as plt
def MCtrap_llplot():
    DTS = np.floor(np.power(2,np.arange(0,23,0.2))).astype(int)
    errors = np.array([(abs(trapezium(n)-exact(0,1)))/(exact(0,1)) for n in DTS])
    MCerrors = np.array([(abs(MCtrapezium(n,100)-exact(0,1)))/(exact(0,1)) for n in DTS])
    plt.plot(np.log(DTS)/np.log(10),np.log(errors)/np.log(10), label = "OG trap")
    # plt.plot(np.log(DTS)/np.log(10),np.log(errors*0.90)/np.log(10), label = "adj OG trap")
    plt.plot(np.log(DTS)/np.log(10),np.log(MCerrors)/np.log(10), label = "MC trap")
    dgs = np.arange(2,3.5,0.5)
    for l in dgs:
        ref = np.array([pow(1/d,l) for d in DTS])
        plt.plot(np.log(DTS)/np.log(10),np.log(ref)/np.log(10),label =f"$\Delta x$**{l}",linestyle="dashed")

    plt.xlabel(f"-log10($\Delta x$)")
    plt.ylabel("log10(%error)")
    plt.legend()
    #plt.title("log log plot")
    # plt.savefig("../../latex/main paper/plots/MCtrap.png",dpi=300)
    plt.show()

MCtrap_llplot()

# %%
import matplotlib.pyplot as plt
def MCtrap_llplot():
    DTS = np.floor(np.power(2,np.arange(0,18,0.1))).astype(int)
    errors = np.array([(abs(trapezium(n)-exact(0,1)))/(exact(0,1)) for n in DTS])
    MCerrors = np.array([(abs(MCtrapezium(n,100)-exact(0,1)))/(exact(0,1)) for n in DTS])
    plt.plot(np.log(DTS)/np.log(10),np.log(errors)/np.log(10), label = "OG trap")
    # plt.plot(np.log(DTS)/np.log(10),np.log(errors*0.90)/np.log(10), label = "adj OG trap")
    plt.plot(np.log(DTS)/np.log(10),np.log(MCerrors)/np.log(10), label = "MC trap")
    dgs = np.arange(2,3.5,0.5)
    for l in dgs:
        ref = np.array([pow(1/d,l) for d in DTS])
        plt.plot(np.log(DTS)/np.log(10),np.log(ref)/np.log(10),label =f"h**{l}",linestyle="dashed")

    plt.xlabel("-log10(h)")
    plt.ylabel("log10(%error)")
    plt.legend()
    #plt.title("log log plot")
    plt.rcParams.update({'font.size': 14})
    plt.savefig("../../latex/presentation (dutch)/imgs/trapMC.png",dpi=300,bbox_inches='tight')
    plt.show()

MCtrap_llplot()
